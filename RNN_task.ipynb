# %%
import pandas as pd
import numpy as np
import keras
from tensorflow.keras.optimizers import RMSprop,Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import random
import time
import os

# %%
df=pd.read_csv("dataset.csv", sep=",")

# %%
Marque = df.loc[:,"Marque"]
Ref = df.loc[:,"Reference"]

# %%
Marque
# Out:
# 0      Etat Libre dOrange
# 1             Ted Lapidus
# 2                 Lancome
# 3                   Guess
# 4                 Pitbull
#               ...
# 501                 Kenzo
# 502       Lolita Lempicka
# 503         Salvador Dali
# 504             Halloween
# 505              Oriflame
# Name: Marque, Length: 506, dtype: object

# %%
def clean(string):
    a1=string.replace("Eau de Parfum","")
    a2=a1.replace("mixte","")
    a3=a2.replace("femme","")
    a4=a3.replace("homme","")
    a5=a4.replace("Eau de Toilette","")
    a6=a5.replace("pour","")
    return a6.rstrip()

# %%
Marque_input=[i for i in Marque]
Ref_input=[clean(i) for i in Ref]
Ref_input
# Out:
# ['Hermann a Mes Cotes Me Paraissait Une Ombre',
#  'Oud Blanc',
#  'La Nuit Tresor Intense',
#  'Seductive Noir',
#  'Pitubull Woman',
#  'Fairy Love',
#  'Hot Couture',
#  'Tag Him huile parfumee',
#  'Sweet Sixteen Coral',
#  'Icon Collection 90 Pure White',
#  'Indonesian Oud',
#  'Italian Bergamot',
#  'Portrayal',
#  'Incense Wood',
#  'Ciel',
#  'Splendida Patchouli Tentation',
#  'Sheer Beauty',
#  'Glam Jasmine',
#  'Wanted By Night',
#  'Marwah',
#  'Adwaa Al Sharq huile parfumee',
#  'Donna',
#  'Amor Amor',
#  'Pour Homme',
#  'Charlie Blue Eau Fraiche',
#  'Yellow Diamond',
#  'Thalasso Therapy',
#  'Remarquables Tinhare',
#  'Inara White',
#  'Jontue eau de cologne',
#  'Promise Me Intense',
#  'Kitten Fur eau de cologne',
#  'EXOTIC 74',
#  'Ambre',
#  'Shalimar',
#  'Miss Ap',
#  'Pour Elle',
#  'Posh On The Green',
#  'Black for Her',
#  'Omnia Coral',
#  'Meliora',
#  'La Yuqawam',
#  'Green Tea eau de cologne',
#  "Katy Perry's Mad Love",
#  'Mora Bella',
#  "L'Initial",
#  'Eros',
#  'Paris Oud',
#  'Mon Guerlain Bloom of Rose',
#  'Fever',
#  'REPLICA Sailing Day',
#  'Z Zegna Intenso',
#  'Mignon Black',
#  'In the Mood for Oud',
#  'Tre',
#  'Miss Boucheron',
#  'Cabotine de Gres',
#  'Dune',
#  'Far Away Glamour',
#  'Too Feminine',
#  'Paris',
#  'La Vie Est Belle En Rose',
#  '5th Avenue NYC',
#  'Pleats Please',
#  'Rush',
#  'Wanderer',
#  'Ralph',
#  'My Burberry',
#  'LEau',
#  'Honey eau de cologne',
#  'Crystal Noir',
#  'Green Tea Lavender',
#  'Mysterial Oud',
#  'Paloma Picasso',
#  'Pineapple eau de cologne',
#  'Thunderstorm eau de cologne',
#  'Hayba',
#  "Pirates' Grand Reserve",
#  'Casamorati 1888 Gran Ballo',
#  'Tea Tonique',
#  'Diamond Petals',
#  'Oud Malaki',
#  'Rose',
#  'Y',
#  'Pour Femme Elixir',
#  'Anastasia',
#  'Red Code',
#  'Clean Windows eau de cologne',
#  'Icon Collection 06 Black Platinum',
#  'Dolce di Giorno',
#  'Her',
#  'Lumiere Doree',
#  'Tommy Girl',
#  "L'Eau d'Issey Shades of Kolam",
#  'Classic Motion',
#  'Musk spray corporel',
#  "Patchouli N' Roses",
#  'Orchid Noir',
#  'Dylan Turquoise Pour Femme',
#  "Reve d'Infini",
#  'Danger parfum',
#  'Be Delicious',
#  'Turmeric eau de cologne',
#  'Sensual Touch',
#  'Musk Extreme',
#  'Night',
#  'Eau So Party',
#  'Supremacy Pour Femme Purple',
#  'Madame Rochas',
#  'Maxima',
#  'Man',
#  'Midnight Oud',
#  'Shaghaf',
#  'Red',
#  'Terracotta Le Parfum',
#  'Persian Dream',
#  'Romantic Lady',
#  'Shi',
#  'Accord Oud',
#  'Zodiac Collection Aries',
#  'Zeus Pour Femme',
#  'Ruby Velvet',
#  'Gold',
#  'Green Tea Cherry Blossom',
#  'Live Irresistible Blossom Crush',
#  'Sport',
#  'Dangerous Woman',
#  'Bois Blonds parfum',
#  'Via Camerelle',
#  'Casamorati 1888 Bouquet Ideale',
#  'Fresh Linens',
#  'Florentine Iris',
#  'Touch of Pink',
#  'Attar Al Boruzz Lamaat Musk Tabriz',
#  'Fantasy',
#  'White Touch',
#  'Chantal',
#  'Dahlia Divin Eau Initiale',
#  'Platinum Oud 50 years',
#  'Romantic Blossom',
#  'Romance Rose',
#  'Oudh 36',
#  'Aqua Motu Intense',
#  'Pour Homme Oud Noir',
#  'Le Chevrefeuille',
#  'Love Nirvana Dream deodorant et spray corps',
#  'Eternity Summer 2020',
#  'Metal Chypre',
#  'Passion',
#  'Energizing Woman',
#  'Lover',
#  'Insolence',
#  'Daring Woman',
#  'Candy Florale',
#  'Pomegranate',
#  'Magnificent Blue Pour Homme',
#  'Lovestruck',
#  'Mirsaal Of Trust',
#  'You',
#  'Cabotine Rose',
#  'Dione',
#  'Marijuana',
#  'Naomi Campbell',
#  'Silhouette In Bloom',
#  'Gold Man',
#  "L'aventurier",
#  'Oh Ma Biche',
#  'Oud eau de cologne',
#  'Fuzzy Nave eau de cologne',
#  'Bohemian Garden',
#  'Libre',
#  'On the Edge',
#  'Gold',
#  'Noora huile parfumee',
#  'Edition One Women',
#  'Candy Kiss',
#  'Belle',
#  'Jungle Snake',
#  'Shalimar',
#  'Dream Bright Gold',
#  'Fancy Girl',
#  'Bella Rosa',
#  "Les Absolus d'Orient Encens Mythique",
#  'White Collection Extraordinary',
#  'Coriandre',
#  'Be Happy Feel Good',
#  'by Marciano',
#  'Heliotrope',
#  'Brazilian Crush Cheirosa 39 Brume Parfumee Corps et Cheveux',
#  'Levriero Collection Donna',
#  '5th Avenue',
#  'Possess The Secret',
#  'Paradise Found',
#  'Liquid Sun',
#  'Petite Jeanne Best Friends Forever',
#  'Faith',
#  'Aloe Vera eau de cologne',
#  'Boucheron',
#  'Hatkora Wood',
#  'Bergamote  recharge',
#  'Vanilla',
#  'CK Everyone',
#  "Katy Perry's Indi Visible",
#  'Lily of The Valley eau de cologne',
#  'Dahlia Divin Le Nectar de Parfum',
#  'Patchouli',
#  'Deep Blue',
#  'La Nuit Tresor Nude',
#  'Emporio Diamonds Rose',
#  'London Berry',
#  'Portfolio Imperial Oud',
#  'Pour Lui In Black',
#  'Elixir Sublime',
#  'Ayurveda',
#  "L'Eau Eau De Parfum",
#  'Sotoor Seen',
#  'Milize',
#  'Amber eau de cologne',
#  'Les Compositions Parfumees Velvet Plum',
#  'Noora huile parfumee',
#  'Definition',
#  'Lady Intense parfum',
#  'Maroussia',
#  'Marry Me',
#  'Sweet Like Candy',
#  'Kelp eau de cologne',
#  'Opera',
#  'Muse de Rochas',
#  'Dior Addict',
#  'BOSS Bottled',
#  'Hayati',
#  'Nahema',
#  'Eau Parfumee Au The Vert eau de cologne',
#  'Debut',
#  'Precious Silver',
#  'Amber Oud Tobacco Edition',
#  'La Voile Rouge',
#  'Halloween',
#  'Zahra huile parfumee',
#  'Pomelo Paradis parfum',
#  'JHL eau de cologne',
#  'Supremacy Pour Femme Pink',
#  'Yes I Am Pink First',
#  'Les Signes de Gres Extreme Purete',
#  'Knowing',
#  'Les Compositions Parfumees Infinite Shine',
#  'Dare',
#  'Petite Jeanne Go For It',
#  'Pegaso',
#  'One Love',
#  'Provocative Woman',
#  'Queen of Seduction',
#  'Mon Guerlain Intense',
#  'Miracle Blossom',
#  'Neroli eau de cologne',
#  'Nisean',
#  'Artisan Blu',
#  'Her Blossom',
#  'REPLICA Music Festival',
#  'Black Man',
#  'Terra Di Gioia',
#  'Dia',
#  'Soleil',
#  'RSVP',
#  'Giorgio',
#  'Ornament Pour Homme',
#  'Her London Dream',
#  'Fruity Rhythm',
#  'Charlie Gold Eau Fraiche',
#  'Gold Yvesse',
#  'Z Zegna Uomo',
#  '1920',
#  'Pure XS Night',
#  'Bohemian Garden',
#  'Lovegrass',
#  'Rocky Man Silver',
#  'Glam Rouge',
#  'Myths',
#  'Perpetual Silver Pearl',
#  'Madame Gres',
#  'Portfolio Neroli Canvas',
#  'Une Nuit Magnetique  recharge',
#  'Elle',
#  'Une Histoire de Femme Sensuelle',
#  'Scent for Men Fresh Citrus',
#  'Wish Pink Diamond',
#  'Eau Parfumee Au The Blanc eau de cologne',
#  'Light di Gioia',
#  'Lotus Desire spray corporel',
#  'Perles de Lalique',
#  'Guilty Cologne Pour Homme',
#  "J'adore",
#  'Jacquard',
#  'Eaudemoiselle de Givenchy Eau Florale',
#  'Legend',
#  'Sweet Sixteen Yellow',
#  'Lovely U',
#  'Rabwa huile parfumee',
#  'Lush Coast Santorini Neroli Water spray corporel',
#  'Patchouli Elixir',
#  'ONESPIRIT',
#  'Prickly Pear eau de cologne',
#  'Ambergris eau de cologne',
#  'Dolce Vita eau de toilette',
#  'Blu Women',
#  'Scandal  edition limitee',
#  'Aurum',
#  'Between The Sheets eau de cologne',
#  'Only The Brave Street',
#  'Xperience',
#  'Le Voluttuose Notturno Fiorentino',
#  'Club de Nuit Milestone',
#  'Sunrise',
#  'Touch for Women',
#  'Antonietta',
#  'Lolita Land',
#  'Rogue Love',
#  'Poison Girl',
#  'Ari by Ariana Grande',
#  'Viva La Juicy Noir',
#  'Arcipelago Women',
#  'REPLICA Springtime in a Park',
#  'Rosewood Amor',
#  'Italian Leather All Time Classic',
#  'Jean Louis Scherrer 1979',
#  'La Ronde des Fleurs Musc Ambre',
#  'Charlie White',
#  'Code Absolu',
#  'Journey',
#  'Adventure for Her',
#  'Violet eau de cologne',
#  'Eden',
#  'Oiseaux de Nuit Nuit et Confidences',
#  'Sweet Romance',
#  'Chloe',
#  'Rogue',
#  'Pour Lui',
#  'Fiorella',
#  "Idole L'Intense",
#  'Laundromat eau de cologne',
#  'Platinum Rush',
#  'Truth for Men',
#  'Les Compositions Parfumees Leather Copper',
#  'Eve Confidence',
#  'Amo Ferragamo',
#  'Sunshine',
#  'Encanto Fascinating',
#  'Kashaf',
#  'Liu',
#  'Valentina',
#  'Viva La Juicy Rose',
#  'Mademoiselle Rochas In Black',
#  "Katy Perry's Indi",
#  'Miss Dior Blooming Bouquet',
#  'Starlight',
#  'Edge',
#  'For Women',
#  'In Red',
#  'HUGO Reversed',
#  'Cannabis Garden',
#  'Rose Pompon',
#  'Attaquer Le Soleil Marquis De Sade',
#  'Innovation',
#  'Oil Fiction',
#  'Rebelle',
#  'Patchouli Blanc',
#  'Lovely Me',
#  'Body',
#  'Lapidus Women',
#  'Not a Perfume Superdose',
#  'Aqua Allegoria Granada Salvia',
#  'Nina Rose Garden',
#  'Rem',
#  'Wild Flowers',
#  'Jaipur Bracelet',
#  'Love Story Eau Sensuelle',
#  'Mad Madame',
#  "Forever Touche d'Argent",
#  'Essential for Men',
#  "J'adore Infinissime",
#  'Coco Figue',
#  'Casamorati 1888 Dama Bianca',
#  'Free Spirit',
#  'Heartbreaker',
#  "L'Eau d'Issey Pure Nectar de Parfum",
#  'Noa',
#  'Eau de Givenchy eau de toilette',
#  'Cashmere Musc',
#  'Intense Oud',
#  'To Be Goodvibes',
#  'Free Wave',
#  'Modest Une Pour Homme',
#  'Escentric 02',
#  'Rumz Al Rasasi Zebra Pour Elle',
#  'Baby Powder eau de cologne',
#  'REPLICA By the Fireplace',
#  'Cassandra Rose Jasmine',
#  'Man X',
#  'Wet Garden eau de cologne',
#  'Makkah huile parfumee',
#  'Fantabulous',
#  'Myth Wood',
#  'Kun Mukhtalifan Women',
#  'Explorer',
#  'Celline',
#  'Forever Classic Never Boring for Her',
#  'Osmond de Noir',
#  'Splendida Tubereuse Mystique',
#  'Eros Pour Femme',
#  'Gabriela Sabatini',
#  'Zodiac Collection Leo',
#  'Charlie Red',
#  'Forever',
#  'Hypnose',
#  'Noble Fig',
#  'My NY',
#  'Mountain Laurel eau de cologne',
#  "J'adore Roller Pearl  roll on",
#  'Iris Rebelle parfum',
#  'Coupe',
#  'Sehr Al Sheila',
#  'Figment',
#  'Caipirinha eau de cologne',
#  'La Nuit Tresor Musc Diamant',
#  'Lilac',
#  'Rose Silence',
#  'Heliotrope',
#  'Tangerine eau de cologne',
#  'Blossom Love',
#  'Vetiver Insolent',
#  'Mademoiselle Rochas Couture',
#  'Io Capri parfum',
#  'Arcipelago Women',
#  'Rem',
#  'Faten White',
#  'Bois Royal',
#  'Verde di Mare',
#  'Sparkling Blush',
#  'Blue Orchid',
#  'Sunflowers Summer Bloom',
#  'Noble VII Cosmos Flower',
#  'Sel de Vetiver',
#  'Illicit Flower',
#  'Musk Malaki',
#  'Roma Rosa',
#  'Amour De Cacao',
#  'Femme',
#  'Omnia Crystalline',
#  'Magic Woman',
#  'Dazzle Intense',
#  'Jump Up and Kiss Me Hedonistic parfum',
#  'CK One',
#  'Ungaro',
#  'Dhan Oudh Al Combodi',
#  'Floral',
#  'Tomato eau de cologne',
#  'Natural Vitality',
#  'Laguna',
#  'Wildflowers eau de cologne',
#  'Donna Pink Marina',
#  'BOSS The Scent Private Accord',
#  'Rose Tangerine',
#  'La Belle Le Parfum',
#  "L'Eau d'Issey",
#  'Amber Santal',
#  'Shuhrah Pour Femme',
#  'REPLICA Matcha Meditation',
#  'Guess',
#  'Couture Couture',
#  'Pink Yvesse',
#  'Olympea Legend',
#  'Wish',
#  'Piece Unique',
#  'Pixie Dust eau de cologne',
#  'Quatre Absolu de Nuit',
#  'Signorina Eleganza',
#  'Rose de Caroline',
#  'Portfolio Royale Stallion',
#  'Amore Mio Forever',
#  'Iconic Blend',
#  'Cinema',
#  'Atifa Blanche',
#  'Sharina Mukhallat Dhanel Oudh huile parfumee',
#  'Libre Intense',
#  'Swimming Pool eau de cologne',
#  'Wave',
#  'Classica Women',
#  'Love at First Glow',
#  'Invictus Legend',
#  'X Limited',
#  'Prerogative',
#  'Patchouli Wood',
#  'Le Jasmine',
#  'Rosewood',
#  'Jeanne Lanvin',
#  'Primal Code',
#  'Memoir',
#  'Original eau de cologne sans vaporisateur',
#  'Sensity Sun Sparkle eau de cologne',
#  'Daisy Dream Forever',
#  'Guilty Absolute',
#  'Flower by Kenzo brume  cheveux et corps',
#  'Lolita Lempicka Mon Premier Parfum',
#  'Sunrise in Cadaques',
#  'Man Shot',
#  'Giordani Gold Essenza parfum']

# %%
concat_marque = '\n'.join(Marque_input).lower()
concat_Ref = '\n'.join(Ref_input).lower()

# %%
chars_marque,chars_Ref = sorted(list(set(concat_marque))),sorted(list(set(concat_Ref)))

# %%
num_char_marque,num_char_ref=len(chars_marque),len(chars_Ref)

# %%
char2idx_marque = dict((c, i) for i, c in enumerate(chars_marque))
idx2char_marque = dict((i, c) for i, c in enumerate(chars_marque))

char2idx_ref = dict((c, i) for i, c in enumerate(chars_Ref))
idx2char_ref = dict((i, c) for i, c in enumerate(chars_Ref))

# %%
max_sequence_length_marque = max([len(name) for name in Marque_input])
max_sequence_length_ref = max([len(name) for name in Ref_input])

# %%
print('--------------------------Marque---------------------------------------')
print('Total chars: {}'.format(num_char_marque))
print('Corpus length:', len(concat_marque))
print('Number of names: ', len(Marque_input))
print('Longest name: ', max_sequence_length_marque)
print('--------------------------Reference---------------------------------------')
print('Total chars: {}'.format(num_char_marque))
print('Corpus length:', len(concat_Ref))
print('Number of names: ', len(Ref_input))
print('Longest name: ', max_sequence_length_ref)
# Out:
# --------------------------Marque---------------------------------------
# Total chars: 36
# Corpus length: 6109
# Number of names:  506
# Longest name:  27
# --------------------------Reference---------------------------------------
# Total chars: 36
# Corpus length: 8363
# Number of names:  506
# Longest name:  59

# %%
step_length = 1   
epochs = 50       
batch_size = 64    
latent_dim = 128   
dropout_rate = 0.2 
verbosity = 0     
gen_amount = 10

# %%
sequences = []
next_chars = []
for i in range(0, len(concat_marque) -max_sequence_length_marque, step_length):
    sequences.append(concat_marque[i: i + max_sequence_length_marque])
    next_chars.append(concat_marque[i + max_sequence_length_marque])

num_sequences = len(sequences)

for i in range(20):
    print('X=[{}]   y=[{}]'.replace('\n', ' ').format(sequences[i], next_chars[i]).replace('\n', ' '))
# Out:
# X=[etat libre dorange ted lapi]   y=[d]
# X=[tat libre dorange ted lapid]   y=[u]
# X=[at libre dorange ted lapidu]   y=[s]
# X=[t libre dorange ted lapidus]   y=[ ]
# X=[ libre dorange ted lapidus ]   y=[l]
# X=[libre dorange ted lapidus l]   y=[a]
# X=[ibre dorange ted lapidus la]   y=[n]
# X=[bre dorange ted lapidus lan]   y=[c]
# X=[re dorange ted lapidus lanc]   y=[o]
# X=[e dorange ted lapidus lanco]   y=[m]
# X=[ dorange ted lapidus lancom]   y=[e]
# X=[dorange ted lapidus lancome]   y=[ ]
# X=[orange ted lapidus lancome ]   y=[g]
# X=[range ted lapidus lancome g]   y=[u]
# X=[ange ted lapidus lancome gu]   y=[e]
# X=[nge ted lapidus lancome gue]   y=[s]
# X=[ge ted lapidus lancome gues]   y=[s]
# X=[e ted lapidus lancome guess]   y=[ ]
# X=[ ted lapidus lancome guess ]   y=[p]
# X=[ted lapidus lancome guess p]   y=[i]

# %%
X = np.zeros((num_sequences, max_sequence_length_marque, num_char_marque), dtype=np.bool)
Y = np.zeros((num_sequences, num_char_marque), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for j, char in enumerate(sequence):
        X[i, j, char2idx_marque[char]] = 1
    Y[i, char2idx_marque[next_chars[i]]] = 1
    
print('X shape: {}'.format(X.shape))
print('Y shape: {}'.format(Y.shape))
#print(X[0])
#print(Y[0])
# Out:
# X shape: (6082, 27, 36)
# Y shape: (6082, 36)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_2084/4069062121.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X = np.zeros((num_sequences, max_sequence_length_marque, num_char_marque), dtype=np.bool)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_2084/4069062121.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((num_sequences, num_char_marque), dtype=np.bool)

# %%
model = Sequential()
model.add(LSTM(latent_dim, 
               input_shape=(max_sequence_length_marque, num_char_marque),  
               recurrent_dropout=dropout_rate))
model.add(Dense(units=num_char_marque, activation='softmax'))

optimizer = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               84480
#
#  dense (Dense)               (None, 36)                4644
#
# =================================================================
# Total params: 89,124
# Trainable params: 89,124
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\sykze\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
start = time.time()
print('Start training for {} epochs'.format(epochs))
history = model.fit(X, Y, epochs=epochs, batch_size=batch_size, verbose=verbosity)
end = time.time()
print('Finished training - time elapsed:', (end - start)/60, 'min')
# Out:
# Start training for 50 epochs
# Finished training - time elapsed: 2.8524643182754517 min

# %%
def generate_marque():
    r = np.random.choice(len(concat_marque)-1)
    r2 = r-max_sequence_length_marque

    sequence = concat_marque[r2:r-1] + '\n'

    new_names = []
    #print(sequence)
    while len(new_names) < 1:

        x = np.zeros((1, max_sequence_length_marque, num_char_marque))
        for i, char in enumerate(sequence):
            x[0, i, char2idx_marque[char]] = 1

        probs = model.predict(x, verbose=0)[0]
        probs /= probs.sum()
        next_idx = np.random.choice(len(probs), p=probs)   
        next_char = idx2char_marque[next_idx]   
        sequence = sequence[1:] + next_char

        if next_char == '\n':

            gen_name = [name for name in sequence.split('\n')][1]

            if len(gen_name) > 4 and gen_name[0] == gen_name[1]:
                gen_name = gen_name[1:]

            if len(gen_name) > 4 and len(gen_name) <= 7:

                if gen_name not in Marque_input + new_names:
                    new_names.append(gen_name.capitalize())
                    return gen_name.capitalize()

# %% [markdown]
# <p> Generate nom d'une marque </p>

# %%
#for _ in range(200):
#    if generate_marque() in Marque_input:
#        pass
#    else:
 #       print(generate_marque())
#------------------------------------Nom intéressant à choisir-----------------------------------------------
#Camuto
#Gabred
#Licobs
#Revlon

# %%
sequences = []
next_chars = []
for i in range(0, len(concat_Ref) -max_sequence_length_ref, step_length):
    sequences.append(concat_Ref[i: i + max_sequence_length_ref])
    next_chars.append(concat_Ref[i + max_sequence_length_ref])

num_sequences = len(sequences)

for i in range(20):
    print('X=[{}]   y=[{}]'.replace('\n', ' ').format(sequences[i], next_chars[i]).replace('\n', ' '))
# Out:
# X=[hermann a mes cotes me paraissait une ombre oud blanc la nu]   y=[i]
# X=[ermann a mes cotes me paraissait une ombre oud blanc la nui]   y=[t]
# X=[rmann a mes cotes me paraissait une ombre oud blanc la nuit]   y=[ ]
# X=[mann a mes cotes me paraissait une ombre oud blanc la nuit ]   y=[t]
# X=[ann a mes cotes me paraissait une ombre oud blanc la nuit t]   y=[r]
# X=[nn a mes cotes me paraissait une ombre oud blanc la nuit tr]   y=[e]
# X=[n a mes cotes me paraissait une ombre oud blanc la nuit tre]   y=[s]
# X=[ a mes cotes me paraissait une ombre oud blanc la nuit tres]   y=[o]
# X=[a mes cotes me paraissait une ombre oud blanc la nuit treso]   y=[r]
# X=[ mes cotes me paraissait une ombre oud blanc la nuit tresor]   y=[ ]
# X=[mes cotes me paraissait une ombre oud blanc la nuit tresor ]   y=[i]
# X=[es cotes me paraissait une ombre oud blanc la nuit tresor i]   y=[n]
# X=[s cotes me paraissait une ombre oud blanc la nuit tresor in]   y=[t]
# X=[ cotes me paraissait une ombre oud blanc la nuit tresor int]   y=[e]
# X=[cotes me paraissait une ombre oud blanc la nuit tresor inte]   y=[n]
# X=[otes me paraissait une ombre oud blanc la nuit tresor inten]   y=[s]
# X=[tes me paraissait une ombre oud blanc la nuit tresor intens]   y=[e]
# X=[es me paraissait une ombre oud blanc la nuit tresor intense]   y=[ ]
# X=[s me paraissait une ombre oud blanc la nuit tresor intense ]   y=[s]
# X=[ me paraissait une ombre oud blanc la nuit tresor intense s]   y=[e]

# %%
X = np.zeros((num_sequences, max_sequence_length_ref, num_char_ref), dtype=np.bool)
Y = np.zeros((num_sequences, num_char_ref), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for j, char in enumerate(sequence):
        X[i, j, char2idx_ref[char]] = 1
    Y[i, char2idx_ref[next_chars[i]]] = 1
    
print('X shape: {}'.format(X.shape))
print('Y shape: {}'.format(Y.shape))
#print(X[0])
#print(Y[0])
# Out:
# X shape: (8304, 59, 39)
# Y shape: (8304, 39)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_2084/4250691270.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X = np.zeros((num_sequences, max_sequence_length_ref, num_char_ref), dtype=np.bool)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_2084/4250691270.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((num_sequences, num_char_ref), dtype=np.bool)

# %%
model2 = Sequential()
model2.add(LSTM(latent_dim, 
               input_shape=(max_sequence_length_ref, num_char_ref),  
               recurrent_dropout=dropout_rate))
model2.add(Dense(units=num_char_ref, activation='softmax'))

optimizer = Adam(lr=0.01)
model2.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 128)               86016
#
#  dense_5 (Dense)             (None, 39)                5031
#
# =================================================================
# Total params: 91,047
# Trainable params: 91,047
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time.time()
print('Start training for {} epochs'.format(epochs))
history = model2.fit(X, Y, epochs=epochs, batch_size=batch_size, verbose=verbosity)
end = time.time()
print('Finished training - time elapsed:', (end - start)/60, 'min')
# Out:
# Start training for 50 epochs
# Finished training - time elapsed: 12.147922281424204 min

# %%
def generate_Ref():
    r = np.random.choice(len(concat_Ref )-1)
    r2 = r-max_sequence_length_ref

    sequence = concat_Ref[r2:r-1] + '\n'

    new_names = []
    #print(sequence)
    while len(new_names) < 1:

        x = np.zeros((1, max_sequence_length_ref, num_char_ref))
        for i, char in enumerate(sequence):
            x[0, i, char2idx_ref[char]] = 1

        probs = model2.predict(x, verbose=0)[0]
        probs /= probs.sum()
        next_idx = np.random.choice(len(probs), p=probs)   
        next_char = idx2char_ref[next_idx]   
        sequence = sequence[1:] + next_char

        if next_char == '\n':

            gen_name = [name for name in sequence.split('\n')][1]

            if len(gen_name) > 4 and gen_name[0] == gen_name[1]:
                gen_name = gen_name[1:]

            if len(gen_name) > 4 and len(gen_name) <= 7:

                if gen_name not in Ref_input + new_names:
                    new_names.append(gen_name.capitalize())
                    return gen_name.capitalize()

# %%
import random
for _ in range(500):
    word=""
    for i in range(random.randint(1,4)):
        word+=generate_Ref()+" "
    print(word)
#Forever Suprême
#Vences Faith Ambre Bouquet 
#J'adore Ambre 
#Intense Flowers 
#Miris Paris 
#Elixir Rebella 
#Celline Man x Olyfet 
#Flowers La vie 
#Vanilla Legend
# Out:
# Dione
# Tanger Oudh 36 Petiver Shaghaf
# Fever Dnine
# Rique Kashaf Arburu
# Fantasy Mirit Lavance
# Dazzle  In yve Rebelle
# Lover
# Arcipel
# Nythe
# Flowers La vie
# Haybeti Meliora Iscasha Citrus
# Rebelle
# Valique Scherle Faith Daore
# Y oud
# J'adore On girl Encant
# Hayasia Pegaso Cinema
# Lilac Seduc Sport
# Erosi Vanilla Degend
# Bruth Shaghaf Catina Incense
# Shantal Lomar
# J'adore Flowers
# Rebelle Lilac Wante
# Jonuer
# Dione Miancas Incense
# Forever Cones Knthe
# Vanill Vanilla Coupe Intense
# Sport
# Hayba Mignod Bouche
# Imone Hayapi Prick
# In red Pegaso Lonuois Guess
# Hayba
# Women Hayba Celline Debut
# Gress Femme Shaghaf
# Achas Journey Night Hayba
# Man x Blush
# Giorgio Green Swhet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_2084/774264645.py in <module>
#       3     word=""
#       4     for i in range(random.randint(1,4)):
# ----> 5         word+=generate_Ref()+" "
#       6     print(word)
#       7 #Vences Faith Ambre Bouquet
#
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_2084/3872656395.py in generate_Ref()
#      13             x[0, i, char2idx_ref[char]] = 1
#      14
# ---> 15         probs = model2.predict(x, verbose=0)[0]
#      16         probs /= probs.sum()
#      17         next_idx = np.random.choice(len(probs), p=probs)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1980           for step in data_handler.steps():
#    1981             callbacks.on_predict_batch_begin(step)
# -> 1982             tmp_batch_outputs = self.predict_function(iterator)
#    1983             if data_handler.should_sync:
#    1984               context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
